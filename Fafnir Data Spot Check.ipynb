# %%
import pandas as pd
import numpy as np
import re

# %%
fromhdf5 = pd.read_hdf('bdv-data-clean.h5', key='Results')

# %%
fromhdf5.drop('Unnamed: 0', axis=1,inplace=True)

# %%
fromhdf5.set_index('BvD ID number',inplace=True)

# %%
GB07114772 = fromhdf5.loc['GB07114772']
for c in fromhdf5.columns:
    print(c + "----> " + str(GB07114772.loc[c]) )
# Out:
# Company name----> BELVIEW LTD
# Registered number----> 07114772
# Primary UK SIC (2007) code----> 68320.0
# Primary UK SIC (2003) code----> 7032.0
# Primary UK SIC (2003) code.1----> 7032.0
# Primary US SIC code----> 6531.0
# Primary NAICS 2017 code----> 531210.0
# BvD sector----> Property Services
# Date of incorporation----> 02/01/2010
# Status date----> 26/06/2018
# Company status----> Dissolved
# Turnover
# th GBP 2019----> nan
# Turnover
# th GBP 2018----> nan
# Turnover
# th GBP 2017----> nan
# Turnover
# th GBP 2016----> 0.065
# Turnover
# th GBP 2015----> nan
# Turnover
# th GBP 2014----> nan
# Turnover
# th GBP 2013----> nan
# Turnover
# th GBP 2012----> nan
# Turnover
# th GBP 2011----> 68.163
# Profit (Loss) before Taxation
# th GBP 2019----> nan
# Profit (Loss) before Taxation
# th GBP 2018----> nan
# Profit (Loss) before Taxation
# th GBP 2017----> nan
# Profit (Loss) before Taxation
# th GBP 2016----> nan
# Profit (Loss) before Taxation
# th GBP 2015----> nan
# ...
