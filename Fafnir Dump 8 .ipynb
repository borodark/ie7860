# %%
import pandas as pd

# %%
gifi_8 = pd.HDFStore('bdv-gifi-8.h5')
df = gifi_8.get('gifi')
# gifi_joined.close()

# %%
df.head(32)
# Out:
#                  total_assets_less_cur._liab._th_gbp  net_assets_th_gbp  \
# bv_id      year
# GB07114772 2011                                0.313              0.313
#            2012                                0.313              0.313
#            2013                                0.313              0.313
#            2014                                0.313              0.313
#            2015                                0.313              0.313
#            2016                                0.313              0.313
# GB07114798 2011                               -0.436             -0.436
#            2012                               -1.253             -1.253
#            2013                               -2.905             -2.905
#            2014                               -2.761             -2.761
#            2015                               -2.761             -2.761
#            2016                               -2.761             -2.761
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                  total_assets_less_cur._liab._th_gbp  net_assets_th_gbp  \
# bv_id      year
# GB07114772 2011                                0.313              0.313
#            2012                                0.313              0.313
#            2013                                0.313              0.313
#            2014                                0.313              0.313
#            2015                                0.313              0.313
# ...                                              ...                ...
# IE539501   2018                                  NaN                NaN
# IE542126   2017                                  NaN                NaN
# IE548809   2019                                  NaN                NaN
# IE551887   2018                                  NaN                NaN
# IE571196   2017                                  NaN                NaN
#
# ...

# %%
df.to_csv('gifi8.csv')
