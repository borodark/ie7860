# %%
import tensorflow as tf
x = tf.random.normal(shape=(256, 256, 1)) 
tf.image.central_crop(x, 0.75)
# Out:
# <tf.Tensor: shape=(192, 192, 1), dtype=float32, numpy=
# array([[[-1.164246  ],
#         [ 1.2479775 ],
#         [-0.07851087],
#         ...,
#         [ 0.20935607],
#         [-0.53999877],
#         [-0.32971266]],
#
#        [[ 1.7892336 ],
#         [-1.6301129 ],
#         [ 2.9721425 ],
#         ...,
#         [-0.79360175],
#         [ 0.23663121],
#         [-0.6783072 ]],
#
#        [[-1.8575978 ],
#         [-1.0185364 ],
#         [-0.3776231 ],
#         ...,
#         [ 0.8923717 ],
#         [-0.07139032],
#         [-2.0505395 ]],
#
#        ...,
#
#        [[-0.4690953 ],
#         [ 1.2093488 ],
#         [-1.9771258 ],
#         ...,
#         [-0.28868994],
#         [-0.29043284],
#         [-1.0786968 ]],
#
#        [[ 1.2076969 ],
#         [ 1.5728383 ],
#         [-0.27893966],
#         ...,
#         [-0.05469261],
#         [ 0.72609836],
#         [-0.44697967]],
#
#        [[ 0.10767737],
#         [-0.2808425 ],
#         [ 0.06805385],
# ...
